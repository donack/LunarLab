# %%
import plotly.express as px

# %%
pwd
# Out:
# 'C:\\Users\\Donac\\Documents'

# %%
import pandas as pd

# %%
df = pd.read_excel('Good_2015and2016.xlsx')

# %%
df.head()
# Out:
#    Unnamed: 0        Date          Object     File      Time  \
# 0           0  05/24/2015  Langrenus Limb  moon_19  0.213889
# 1           1  05/24/2015  Cleomedes Limb  moon_20  0.218056
# 2           2  05/24/2015      Atlas Limb  moon_21  0.222917
# 3           3  05/24/2015   Petavius Limb  moon_23  0.233333
# 4           4  05/24/2015    Janssen Limb  moon_24  0.238889
#
#            DateTime Month  Year        HA  Expo  ... V6 Area V6 Error.2  \
# 0  5/24/15 05:08:00   May  2015  04:42:00   300  ...    0.67          0
# 1  5/24/15 05:14:00   May  2015  04:48:00   300  ...    0.67          0
# 2  5/24/15 05:21:00   May  2015  04:55:00   300  ...    0.67          0
# 3  5/24/15 05:36:00   May  2015  05:10:00   300  ...    0.67          0
# 4  5/24/15 05:44:00   May  2015  05:17:00   300  ...    0.67          0
#
#       Offset     Error    Slope    Error.1    Intensity  Intensity Error  \
# 0  67.601459  0.164931 -0.060825  0.001075  1149.831277         7.337287
# ...

# %%
fig1 = px.scatter(df, x="Phase", y="Moon_Lat", size = "Relint", color = "DW", animation_frame="Month", hover_name = "Crater")

# %%
fig1.show()
# Out:
# <div>
#
#
#             <div id="6e1f2c3c-95ed-4fff-9515-60cc5b7b5d4d" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6e1f2c3c-95ed-4fff-9515-60cc5b7b5d4d")) {
#                     Plotly.newPlot(
#                         '6e1f2c3c-95ed-4fff-9515-60cc5b7b5d4d',
# ...

# %%
fig2 = px.scatter(df, x="Phase", y="Moon_Lat", size = "Relint", color = "Year", animation_frame="Month", hover_name = "Crater")
fig2.show()
# Out:
# <div>
#
#
#             <div id="6a89c7c5-28df-4417-bc38-c877efb6abf9" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6a89c7c5-28df-4417-bc38-c877efb6abf9")) {
#                     Plotly.newPlot(
#                         '6a89c7c5-28df-4417-bc38-c877efb6abf9',
# ...

# %%
fig3 = px.scatter(df, x="Phase", y="Moon_Lat", size = "Relint", color = "Month", animation_frame="Year", hover_name = "Crater")
fig3.show()
# Out:
# <div>
#
#
#             <div id="19e716ee-a405-4994-8688-bfe641dbd581" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("19e716ee-a405-4994-8688-bfe641dbd581")) {
#                     Plotly.newPlot(
#                         '19e716ee-a405-4994-8688-bfe641dbd581',
# ...
